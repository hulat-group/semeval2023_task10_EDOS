# %% [markdown]
# # Data Augmentation for EDOS
#
# In this notebook, we will explore different data augmentation techniques for generating additional training data from the training dataset:

# %% [markdown]
# First, we install some libraries that we will use:

# %%
# !pip install datasets textaugment transformers nlpaug translators
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.8/dist-packages (2.9.0)
# Requirement already satisfied: textaugment in /usr/local/lib/python3.8/dist-packages (1.3.4)
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.26.1)
# Requirement already satisfied: nlpaug in /usr/local/lib/python3.8/dist-packages (1.1.11)
# Requirement already satisfied: translators in /usr/local/lib/python3.8/dist-packages (5.5.6)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (6.0)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (2.28.2)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2023.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from datasets) (23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.8/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.8/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.12.1)
# Requirement already satisfied: textblob in /usr/local/lib/python3.8/dist-packages (from textaugment) (0.15.3)
# Requirement already satisfied: googletrans in /usr/local/lib/python3.8/dist-packages (from textaugment) (3.0.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.8/dist-packages (from textaugment) (3.6.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from textaugment) (3.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: gdown>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from nlpaug) (4.4.0)
# Requirement already satisfied: pathos>=0.2.9 in /usr/local/lib/python3.8/dist-packages (from translators) (0.3.0)
# Requirement already satisfied: PyExecJS>=1.5.1 in /usr/local/lib/python3.8/dist-packages (from translators) (1.5.1)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.8/dist-packages (from translators) (4.9.2)
# Requirement already satisfied: cryptography>=38.0.1 in /usr/local/lib/python3.8/dist-packages (from translators) (39.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=38.0.1->translators) (1.15.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (3.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from gdown>=4.0.0->nlpaug) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown>=4.0.0->nlpaug) (4.6.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.5.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: ppft>=1.7.6.6 in /usr/local/lib/python3.8/dist-packages (from pathos>=0.2.9->translators) (1.7.6.6)
# Requirement already satisfied: pox>=0.3.2 in /usr/local/lib/python3.8/dist-packages (from pathos>=0.2.9->translators) (0.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (1.26.14)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.8/dist-packages (from gensim->textaugment) (1.7.3)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.8/dist-packages (from gensim->textaugment) (6.3.0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.8/dist-packages (from googletrans->textaugment) (0.13.3)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.8/dist-packages (from httpx==0.13.3->googletrans->textaugment) (2023.1.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.8/dist-packages (from httpx==0.13.3->googletrans->textaugment) (3.0.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.8/dist-packages (from httpx==0.13.3->googletrans->textaugment) (1.3.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.8/dist-packages (from httpx==0.13.3->googletrans->textaugment) (0.9.1)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.8/dist-packages (from httpx==0.13.3->googletrans->textaugment) (1.5.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.8/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans->textaugment) (3.2.0)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.8/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans->textaugment) (0.9.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.8/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans->textaugment) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.8/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans->textaugment) (3.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->textaugment) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->textaugment) (1.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=38.0.1->translators) (2.21)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (1.7.1)

# %%
from datasets import load_dataset
# As the dataset is private, we have to use this: 
access_token="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" # True, for public dataset
dataset_dict = load_dataset("ISEGURA/edos", use_auth_token=access_token)
dataset_dict
# Out:
# WARNING:datasets.builder:Using custom data configuration ISEGURA--edos-3eaaae6cbac3dc24
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/ISEGURA___csv/ISEGURA--edos-3eaaae6cbac3dc24/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['rewire_id', 'text', 'label_sexist', 'label_category', 'label_vector'],
#         num_rows: 9800
#     })
#     test: Dataset({
#         features: ['rewire_id', 'text', 'label_sexist', 'label_category', 'label_vector'],
#         num_rows: 2814
#     })
#     validation: Dataset({
#         features: ['rewire_id', 'text', 'label_sexist', 'label_category', 'label_vector'],
#         num_rows: 1386
#     })
# })

# %% [markdown]
# Data augmentations techniques should only be applied to the training data, so we will only work with this split:

# %%
training_data = dataset_dict['train']
# free some space
del(dataset_dict)
training_data
# Out:
# Dataset({
#     features: ['rewire_id', 'text', 'label_sexist', 'label_category', 'label_vector'],
#     num_rows: 9800
# })

# %%
import nltk
# we need this NLTK's modules for EDA
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4') 
from textaugment import EDA
import nlpaug.augmenter.word as naw # contextualized language model such as BERT to generate new sentences: 

t = EDA()
aug = naw.ContextualWordEmbsAug(model_path='bert-base-uncased', action="insert")

def generate(example):
    original_text = example['text']
    # textaugmenter
    example['text_eda'] = t.synonym_replacement(original_text)
    #NLPAug
    example['text_nlpaug'] = aug.augment(original_text)[0]

    return example


training_data = training_data.map(generate)
training_data
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#   0%|          | 0/9800 [00:00<?, ?ex/s]

# %%
from google.colab import drive
# mount your google drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/Colab Notebooks/data/edos/"
#save to csv
training_data.to_csv(path + "edos_agumented_train.csv", index = None)
print('file saved')
